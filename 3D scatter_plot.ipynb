# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
#%matplotlib notebook

# %%
ax = plt.axes(projection="3d") #creating axis
ax.scatter(100,56,-89)          # plotting a single point
plt.show()
# Out:
# C:\Users\sraji\AppData\Local\Temp\ipykernel_2044\2693482703.py:2: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.scatter(100,56,-89)          # plotting a single point

# %%
ax = plt.axes(projection="3d")
x_data = np.random.randint(0,100,size = (10,))
y_data = np.random.randint(0,100,size = (10,))
z_data = np.random.randint(0,100,size = (10,))
ax.set_title("LiDAR_data")

ax.scatter(x_data,y_data,z_data)
plt.show()
# Out:
# C:\Users\sraji\AppData\Local\Temp\ipykernel_2044\2084476637.py:9: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.scatter(x_data,y_data,z_data)

# %%
import os
from plyfile import PlyData, PlyElement
def read_ply_xyz(filename):
    """ read XYZ point cloud from filename PLY file """
    assert(os.path.isfile(filename))
    with open(filename, 'rb') as f:
        plydata = PlyData.read(f)
        num_verts = plydata['vertex'].count
        vertices = np.zeros(shape=[num_verts, 3], dtype=np.float32)
        vertices[:,0] = plydata['vertex'].data['x']
        vertices[:,1] = plydata['vertex'].data['y']
        vertices[:,2] = plydata['vertex'].data['z']
    return vertices 


li_data = read_ply_xyz("lidar_data.ply")
print(type(li_data))
# Out:
# <class 'numpy.ndarray'>

# %%
li_data.shape
# Out:
# (11998350, 3)

# %%
x_data = li_data[:,0]
y_data = li_data[:,1]
z_data = li_data[:,2]

x = np.random.choice(x_data, size=(300,))
y = np.random.choice(y_data, size=(300,))
z = np.random.choice(z_data, size=(300,))
fig = plt.figure(figsize = (10, 6))

ax = plt.axes(projection="3d")
ax.set_title("LiDAR_data")
ax.set_xlabel("X_axis")
ax.set_ylabel("Y_axis")
ax.set_zlabel("Z_axis")

ax.scatter(x,y,z,c='g')
plt.show()
# Out:
# C:\Users\sraji\AppData\Local\Temp\ipykernel_2044\556593761.py:16: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.scatter(x,y,z,c='g')
